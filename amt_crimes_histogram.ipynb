# %%
# import stuff 
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import altair as alt
import plotly.express as px

# %%
# load the data 
crimes=pd.read_csv('resources/filtered/sacramento_crime_2006_filtered.csv')

# %%
# dataframe info 
crimes
# Out:
#       Unnamed: 0      cdatetime                            address  \
# 0              0    1/1/06 0:00                 3108 OCCIDENTAL DR
# 1              1    1/1/06 0:00                2082 EXPEDITION WAY
# 2              2    1/1/06 0:00                         4 PALEN CT
# 3              3    1/1/06 0:00                     22 BECKFORD CT
# 4              4    1/1/06 0:00                   3421 AUBURN BLVD
# ...          ...            ...                                ...
# 7579        7579  1/31/06 23:36                     26TH ST / G ST
# 7580        7580  1/31/06 23:40                 4011 FREEPORT BLVD
# 7581        7581  1/31/06 23:41                     30TH ST / K ST
# 7582        7582  1/31/06 23:45                 5303 FRANKLIN BLVD
# 7583        7583  1/31/06 23:50  COBBLE COVE LN / COBBLE SHORES DR
#
#                          crimedescr  ucr_ncic_code   latitude   longitude
# 0     10851(A)VC TAKE VEH W/O OWNER           2404  38.550420 -121.391416
# ...

# %%
# histogram of ucr_ncic_code 
fig = px.histogram(crimes, x="ucr_ncic_code", title="Histogram of UCR_NCIC_CODE")
fig.show()
# Out:
# <div>                            <div id="6b3567f8-f08b-4114-8f3c-42c2ce7eb219" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6b3567f8-f08b-4114-8f3c-42c2ce7eb219")) {                    Plotly.newPlot(                        "6b3567f8-f08b-4114-8f3c-42c2ce7eb219",                        [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "ucr_ncic_code=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": [2404, 2204, 2404, 2501, 2299, 2604, 2299, 2308, 2203, 2310, 7000, 2604, 7000, 2604, 2605, 2303, 7000, 2308, 2604, 2605, 2299, 2605, 2399, 2299, 7000, 2999, 2605, 2309, 7000, 2399, 7000, 2204, 2605, 2799, 7
# ...

# %%
# pie chart 
# df = px.data.tips()
# df
# fig = px.pie(crimes, values='ucr_ncic_code', names='crimedescr', width=400, height=800)
# fig.show()
# Out:
# <div>                            <div id="3e921a3d-5024-4e11-adc7-13953cca20ab" class="plotly-graph-div" style="height:800px; width:400px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3e921a3d-5024-4e11-adc7-13953cca20ab")) {                    Plotly.newPlot(                        "3e921a3d-5024-4e11-adc7-13953cca20ab",                        [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "crimedescr=%{label}<br>ucr_ncic_code=%{value}<extra></extra>", "labels": ["10851(A)VC TAKE VEH W/O OWNER", "459 PC  BURGLARY RESIDENCE", "10851(A)VC TAKE VEH W/O OWNER", "476 PC PASS FICTICIOUS CHECK", "459 PC  BURGLARY-UNSPECIFIED", "530.5 PC USE PERSONAL ID INFO", "459 PC  BURGLARY VEHICLE", "484 PC   PETTY THEFT/INSIDE", "459 PC  BURGLARY BUSINESS", "1708 US   THEFT OF MAIL", "ASSAULT WITH WEAPO
# ...
